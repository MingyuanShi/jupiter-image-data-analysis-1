# %%
# %pylab notebook
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
AHA = plt.imread('/home/expshhg2018/SHHG2018/Spectrometer1Results/20181219/spec1__Wed Dec 19 2018_18.00.33_32.tif',)
AHA1 = plt.imread('/home/expshhg2018/SHHG2018/Spectrometer1Results/20181127/20181127_tiff/20181127_spec1_11.tiff',)
AHA2 = plt.imread('/home/expshhg2018/SHHG2018/Spectrometer1Results/20181127/20181127_tiff/20181127_spec1_46.tiff', format=None)
AHA3 = plt.imread('/home/expshhg2018/SHHG2018/Spectrometer1Results/20181127/20181127_tiff/20181127_spec1_42.tiff', format=None)
plt.figure(1)
plt.imshow(AHA)
plt.figure(2)
plt.imshow(AHA2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
v0 = np.sum(AHA[:,780:890], axis = 1)
v1 = np.sum(AHA1[:, 200:500], axis = 1)
v2 = np.sum(AHA2[:, 200:500], axis = 1)
v3 = np.sum(AHA3[:, 200:500], axis = 1)
#print(v1)
plt.figure(3)
plt.plot(v0,label='32_20181219',linewidth=0.5)
plt.plot(v1,label='11',linewidth=0.5)
plt.plot(v2,label='46', linewidth=0.5)
plt.plot(v3,label='42',linewidth=0.5)
legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def background(x):
    back_mean=np.mean(x[:, 1692:2048], axis = 1)
    x_backsubstracted=np.empty([2048, 2048])
    i=1
    j=0
    N=len(x)-1
    #print(len(back_mean), "length of backmean")
    #print(back_mean, "array backmean")
    while i<= N:
        #print(x)
        #print(back_mean[i])
        x_backsubstracted[::,i] = x[::,i]- back_mean[i]
        #print(x_backsubstracted[i,::], "substracted element")                   
        #print(i, "i")
        i = i+1
    plt.figure(3)
    plt.imshow(x_backsubstracted)
    v0_back = np.sum(x_backsubstracted[:,780:890], axis = 1)

    plt.figure(4)
    plt.plot(v0_back,label='32_20181219',linewidth=0.5)

    legend()


        
        #backsub_picture[i,j]= x[j,i]- backmean[i]
        
background(AHA)
# Out:
# <img src="data:image/png;base64,..." width="640">
